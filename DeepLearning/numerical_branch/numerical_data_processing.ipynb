# %% [markdown]
# # Práctica Final del módulo de Machine Learning
# ##### Amparo Alías Cuesta
# **------------------------------------------------------------------------------------------------------------------**

# %% [markdown]
# ## Imports

# %%
import numpy as np
import pandas as pd

import matplotlib.pyplot as plt
import seaborn as sns
from matplotlib.colors import ListedColormap
# %matplotlib inline

cm = plt.cm.RdBu
cm_bright = ListedColormap(['#FF0000', '#0000FF'])

import warnings
warnings.filterwarnings('ignore')

pd.set_option('display.max_columns', 500)
pd.set_option('display.max_rows', 500)

# %%
from datetime import datetime
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### Load data

# %% [markdown]
# Primero de todo, leemos los datos y hacemos una primera visualización de las variables que tenemos:

# %%
data = pd.read_csv('../airbnb-listings.csv', sep = ';')
data.head(3)
# Out:
#          ID                            Listing Url       Scrape ID  \
# 0  15141125  https://www.airbnb.com/rooms/15141125  20170407214119
# 1   9470166   https://www.airbnb.com/rooms/9470166  20170407214119
# 2  17444981  https://www.airbnb.com/rooms/17444981  20170407214119
#
#   Last Scraped                                 Name  \
# 0   2017-04-08           Panoramic charming studio!
# 1   2017-04-08  Comfortable penthouse in the center
# 2   2017-04-08         Cosy Apartment SOL/LA LATINA
#
#                                              Summary  \
# 0  Charming bright and cosy studio in "El Rastro"...
# 1  In the center, recently remodeled, comfortable...
# 2  Nice apartment near Sol and La Latina. Perfect...
#
#                                                Space  \
# 0  It's a bright and cosy studio located in the h...
# 1  Quiet and comfortable space where you can rela...
# 2  Is a really cosy apartment with the best locat...
#
#                                          Description Experiences Offered  \
# 0  Charming bright and cosy studio in "El Rastro"...                none
# 1  In the center, recently remodeled, comfortable...                none
# 2  Nice apartment near Sol and La Latina. Perfect...                none
#
#                                Neighborhood Overview  \
# 0  The studio is located in the remarkable neighb...
# 1  It belongs to the district center of Madrid wh...
# 2  La Latina is well known by El Rastro, the most...
#
#                                                Notes  \
# 0                                                NaN
# 1  A la misma distancia en tiempo podrás acceder ...
# 2  Airport transfer for maximum 4 people, 30€ one...
#
#                                              Transit  \
# 0  The closest metro is La latina which will take...
# 1  The nearest Metro station is Tirso de Molina ,...
# 2  El apartamento es muy céntrico, para visitar e...
#
#                                               Access  \
# 0  The full studio will be entirely to the guests...
# 1  You will be alone, while you are in my flat an...
# 2                                       Toda la casa
#
#                                          Interaction  \
# 0  I am delighted to preform the check in at the ...
# 1  If you have any questions while you are in the...
# 2  I will be happy to help you with whatever you ...
#
#                                          House Rules  \
# 0                                                NaN
# 1  Check ins after 21h to 22h have an extra cost ...
# 2  - Minimizar el ruido a partir de las 22:00 h. ...
#
#                                        Thumbnail Url  \
# 0  https://a0.muscache.com/im/pictures/d1a2212d-c...
# 1  https://a0.muscache.com/im/pictures/3eb59287-8...
# 2  https://a0.muscache.com/im/pictures/de09fac7-9...
#
#                                           Medium Url  \
# 0  https://a0.muscache.com/im/pictures/d1a2212d-c...
# 1  https://a0.muscache.com/im/pictures/3eb59287-8...
# 2  https://a0.muscache.com/im/pictures/de09fac7-9...
#
#                                          Picture Url  \
# 0  https://public.opendatasoft.com/api/v2/catalog...
# 1  https://public.opendatasoft.com/api/v2/catalog...
# 2  https://public.opendatasoft.com/api/v2/catalog...
#
#                                       XL Picture Url    Host ID  \
# 0  https://a0.muscache.com/im/pictures/d1a2212d-c...   96019257
# 1  https://a0.muscache.com/im/pictures/3eb59287-8...    9885245
# 2  https://a0.muscache.com/im/pictures/de09fac7-9...  118059488
#
#                                       Host URL     Host Name  Host Since  \
# 0   https://www.airbnb.com/users/show/96019257        Marina  2016-09-20
# 1    https://www.airbnb.com/users/show/9885245         Jorge  2013-11-08
# 2  https://www.airbnb.com/users/show/118059488  Luis Enrique  2017-02-25
#
#                         Host Location  \
# 0  Madrid, Community of Madrid, Spain
# 1  Madrid, Community of Madrid, Spain
# 2                               Spain
#
#                                           Host About Host Response Time  \
# 0  I have a serious addiction for traveling :0l! ...     within an hour
# 1                                                NaN     within an hour
# 2  Hola a todos! Me llamo Luis Enrique y vivo en ...     within an hour
#
#    Host Response Rate  Host Acceptance Rate  \
# 0               100.0                   NaN
# 1               100.0                   NaN
# 2               100.0                   NaN
#
#                                   Host Thumbnail Url  \
# 0  https://a0.muscache.com/im/pictures/fffbb86e-5...
# 1  https://a0.muscache.com/im/users/9885245/profi...
# 2  https://a0.muscache.com/im/pictures/443f94b3-3...
#
#                                     Host Picture Url Host Neighbourhood  \
# 0  https://a0.muscache.com/im/pictures/fffbb86e-5...                NaN
# 1  https://a0.muscache.com/im/users/9885245/profi...          Hortaleza
# 2  https://a0.muscache.com/im/pictures/443f94b3-3...                NaN
#
#    Host Listings Count  Host Total Listings Count  \
# 0                  2.0                        2.0
# 1                 13.0                       13.0
# 2                  1.0                        1.0
#
#                                   Host Verifications  \
# 0   email,phone,facebook,reviews,jumio,government_id
# 1                          email,phone,reviews,jumio
# 2  email,phone,facebook,reviews,jumio,offline_gov...
#
#                                      Street Neighbourhood  \
# 0  Madrid, Comunidad de Madrid 28005, Spain           NaN
# 1  Madrid, Comunidad de Madrid 28012, Spain           NaN
# 2  Madrid, Comunidad de Madrid 28012, Spain           NaN
#
#   Neighbourhood Cleansed Neighbourhood Group Cleansed    City  \
# 0            Embajadores                       Centro  Madrid
# 1            Embajadores                       Centro  Madrid
# 2            Embajadores                       Centro  Madrid
#
#                  State Zipcode  Market Smart Location Country Code Country  \
# 0  Comunidad de Madrid   28005  Madrid  Madrid, Spain           ES   Spain
# 1  Comunidad de Madrid   28012  Madrid  Madrid, Spain           ES   Spain
# 2  Comunidad de Madrid   28012  Madrid  Madrid, Spain           ES   Spain
#
#     Latitude  Longitude Property Type        Room Type  Accommodates  \
# 0  40.407453  -3.707995          Loft  Entire home/apt             2
# 1  40.408316  -3.705006     Apartment  Entire home/apt             4
# 2  40.413722  -3.706823     Apartment  Entire home/apt             4
#
#    Bathrooms  Bedrooms  Beds  Bed Type  \
# 0        1.0       0.0   1.0  Real Bed
# 1        1.0       1.0   2.0  Real Bed
# 2        1.5       1.0   2.0  Real Bed
#
#                                            Amenities  Square Feet  Price  \
# 0  TV,Internet,Wireless Internet,Kitchen,Pets all...          NaN   50.0
# 1  TV,Internet,Wireless Internet,Air conditioning...          NaN   50.0
# 2  TV,Internet,Wireless Internet,Air conditioning...          NaN   77.0
#
#    Weekly Price  Monthly Price  Security Deposit  Cleaning Fee  \
# 0           NaN            NaN             100.0          20.0
# 1           NaN            NaN             250.0          15.0
# 2           NaN            NaN               NaN          25.0
#
#    Guests Included  Extra People  Minimum Nights  Maximum Nights  \
# 0                2            15               2            1125
# 1                2            25               1            1125
# 2                1             0               1            1125
#
#   Calendar Updated  Has Availability  Availability 30  Availability 60  \
# 0            today               NaN               13               24
# 1       3 days ago               NaN               15               42
# 2       4 days ago               NaN                7               34
#
#    Availability 90  Availability 365 Calendar last Scraped  Number of Reviews  \
# 0               42                66            2017-04-07                 30
# 1               72               347            2017-04-07                 97
# 2               64               155            2017-04-07                  7
#
#   First Review Last Review  Review Scores Rating  Review Scores Accuracy  \
# 0   2016-10-15  2017-03-31                  96.0                    10.0
# 1   2015-12-01  2017-04-04                  81.0                     8.0
# 2   2017-03-06  2017-04-07                  89.0                     9.0
#
#    Review Scores Cleanliness  Review Scores Checkin  \
# 0                       10.0                   10.0
# 1                        8.0                    9.0
# 2                       10.0                    9.0
#
#    Review Scores Communication  Review Scores Location  Review Scores Value  \
# 0                         10.0                    10.0                 10.0
# 1                          9.0                     9.0                  8.0
# 2                         10.0                    10.0                 10.0
#
#   License  Jurisdiction Names Cancellation Policy  \
# 0     NaN                 NaN            moderate
# 1     NaN                 NaN              strict
# 2     NaN                 NaN            moderate
#
#    Calculated host listings count  Reviews per Month  \
# 0                               2               5.11
# 1                              13               5.88
# 2                               1               6.18
#
#                     Geolocation  \
# 0  40.4074526848,-3.70799547544
# 1    40.408315561,-3.7050063857
# 2  40.4137220146,-3.70682311865
#
#                                             Features
# 0  Host Is Superhost,Host Has Profile Pic,Host Id...
# 1  Host Has Profile Pic,Host Identity Verified,Re...
# 2  Host Has Profile Pic,Host Identity Verified,Re...

# %% [markdown]
# ## Work with train dataset

# %%
(train, test) = train_test_split(data, test_size=0.25, random_state=42)

# %%
data = train

# %%
data.head().T
# Out:
#                                                                             9937   \
# ID                                                                          18628
# Listing Url                                    https://www.airbnb.com/rooms/18628
# Scrape ID                                                          20170407214119
# Last Scraped                                                           2017-04-08
# Name                                           Greta Studio Wifi Chueca en Madrid
# Summary                         The small details make this apartment a joyful...
# Space                           The small details make this apartment a joyful...
# Description                     The small details make this apartment a joyful...
# Experiences Offered                                                          none
# Neighborhood Overview           The neighborhood is quiet and friendly, the ne...
# Notes                           Puedes andar poir el centro de Madrid sin tene...
# Transit                         It is best to walk, you are in the city center...
# Access                          If you like, we can include breakfast in the b...
# Interaction                     Puedes contactar conmigo para que te ayude en ...
# House Rules                     No se pueden hacer fiestas para respetar a los...
# Thumbnail Url                                                                 NaN
# Medium Url                                                                    NaN
# Picture Url                     https://public.opendatasoft.com/api/v2/catalog...
# XL Picture Url                                                                NaN
# Host ID                                                                     71597
# Host URL                                  https://www.airbnb.com/users/show/71597
# Host Name                                                            Gema & Jimmy
# Host Since                                                             2010-01-19
# Host Location                                               Madrid, Madrid, Spain
# Host About                      Somos una malagueña y un sueco afincados en Ma...
# Host Response Time                                                 within an hour
# Host Response Rate                                                            100
# Host Acceptance Rate                                                          NaN
# Host Thumbnail Url              https://a0.muscache.com/im/users/71597/profile...
# Host Picture Url                https://a0.muscache.com/im/users/71597/profile...
# Host Neighbourhood                                                       Justicia
# Host Listings Count                                                             1
# Host Total Listings Count                                                       1
# Host Verifications                                   email,phone,facebook,reviews
# Street                          Justicia, Madrid, Comunidad de Madrid 28004, S...
# Neighbourhood                                                            Justicia
# Neighbourhood Cleansed                                                   Justicia
# Neighbourhood Group Cleansed                                               Centro
# City                                                                       Madrid
# State                                                         Comunidad de Madrid
# Zipcode                                                                     28004
# Market                                                                     Madrid
# Smart Location                                                      Madrid, Spain
# Country Code                                                                   ES
# Country                                                                     Spain
# Latitude                                                                  40.4247
# Longitude                                                                -3.69864
# Property Type                                                           Apartment
# Room Type                                                         Entire home/apt
# Accommodates                                                                    2
# Bathrooms                                                                       1
# Bedrooms                                                                        0
# Beds                                                                            1
# Bed Type                                                            Pull-out Sofa
# Amenities                       TV,Wireless Internet,Air conditioning,Kitchen,...
# Square Feet                                                                     0
# Price                                                                          49
# Weekly Price                                                                  310
# Monthly Price                                                                 750
# Security Deposit                                                              100
# Cleaning Fee                                                                   30
# Guests Included                                                                 1
# Extra People                                                                    0
# Minimum Nights                                                                 28
# Maximum Nights                                                               1825
# Calendar Updated                                                       a week ago
# Has Availability                                                              NaN
# Availability 30                                                                 0
# Availability 60                                                                 0
# Availability 90                                                                 0
# Availability 365                                                               99
# Calendar last Scraped                                                  2017-04-08
# Number of Reviews                                                              35
# First Review                                                           2010-05-29
# Last Review                                                            2016-12-28
# Review Scores Rating                                                           89
# Review Scores Accuracy                                                          9
# Review Scores Cleanliness                                                       9
# Review Scores Checkin                                                           9
# Review Scores Communication                                                    10
# Review Scores Location                                                         10
# Review Scores Value                                                             9
# License                                                                       NaN
# Jurisdiction Names                                                            NaN
# Cancellation Policy                                                        strict
# Calculated host listings count                                                  1
# Reviews per Month                                                            0.42
# Geolocation                                          40.4247153175,-3.69863818771
# Features                        Host Has Profile Pic,Is Location Exact,Require...
#
#                                                                             10483  \
# ID                                                                        2752009
# Listing Url                                  https://www.airbnb.com/rooms/2752009
# Scrape ID                                                          20170407214119
# Last Scraped                                                           2017-04-08
# Name                                                 LOCATION-GREAT PRICE-COMFORT
# Summary                         Beautiful apt in Madrid center w all the ameni...
# Space                           +++++++++ https://www.airbnb.es/rooms/6542642 ...
# Description                     Beautiful apt in Madrid center w all the ameni...
# Experiences Offered                                                          none
# Neighborhood Overview           El edificio es muy tranquilo, la finca ha sido...
# Notes                           El apartamento está cuidado al detalle, y siem...
# Transit                         La conexión del apartamento con el transporte ...
# Access                          Servicios: 3 ª planta con ascensor , aire acon...
# Interaction                     Nuestros huéspedes tendrán un teléfono al que ...
# House Rules                     Put off the air conditioning when you go out p...
# Thumbnail Url                   https://a0.muscache.com/im/pictures/36852494/c...
# Medium Url                      https://a0.muscache.com/im/pictures/36852494/c...
# Picture Url                     https://public.opendatasoft.com/api/v2/catalog...
# XL Picture Url                  https://a0.muscache.com/im/pictures/36852494/c...
# Host ID                                                                  14077633
# Host URL                               https://www.airbnb.com/users/show/14077633
# Host Name                                                            David Y Luis
# Host Since                                                             2014-04-09
# Host Location                                  Madrid, Community of Madrid, Spain
# Host About                      We are two young professional guy, very famili...
# Host Response Time                                                 within an hour
# Host Response Rate                                                             98
# Host Acceptance Rate                                                          NaN
# Host Thumbnail Url              https://a0.muscache.com/im/users/14077633/prof...
# Host Picture Url                https://a0.muscache.com/im/users/14077633/prof...
# Host Neighbourhood                                                       Justicia
# Host Listings Count                                                             4
# Host Total Listings Count                                                       4
# Host Verifications                                      email,phone,reviews,jumio
# Street                          Justicia, Madrid, Comunidad de Madrid 28004, S...
# Neighbourhood                                                            Justicia
# Neighbourhood Cleansed                                                Universidad
# Neighbourhood Group Cleansed                                               Centro
# City                                                                       Madrid
# State                                                         Comunidad de Madrid
# Zipcode                                                                     28004
# Market                                                                     Madrid
# Smart Location                                                      Madrid, Spain
# Country Code                                                                   ES
# Country                                                                     Spain
# Latitude                                                                  40.4285
# Longitude                                                                -3.70392
# Property Type                                                           Apartment
# Room Type                                                         Entire home/apt
# Accommodates                                                                    4
# Bathrooms                                                                       1
# Bedrooms                                                                        1
# Beds                                                                            1
# Bed Type                                                                 Real Bed
# Amenities                       TV,Internet,Wireless Internet,Air conditioning...
# Square Feet                                                                   NaN
# Price                                                                         105
# Weekly Price                                                                  NaN
# Monthly Price                                                                3700
# Security Deposit                                                               88
# Cleaning Fee                                                                   29
# Guests Included                                                                 2
# Extra People                                                                   15
# Minimum Nights                                                                  1
# Maximum Nights                                                                 62
# Calendar Updated                                                        yesterday
# Has Availability                                                              NaN
# Availability 30                                                                13
# Availability 60                                                                30
# Availability 90                                                                49
# Availability 365                                                              324
# Calendar last Scraped                                                  2017-04-08
# Number of Reviews                                                             214
# First Review                                                           2014-04-20
# Last Review                                                            2017-04-04
# Review Scores Rating                                                           97
# Review Scores Accuracy                                                         10
# Review Scores Cleanliness                                                      10
# Review Scores Checkin                                                          10
# Review Scores Communication                                                    10
# Review Scores Location                                                         10
# Review Scores Value                                                            10
# License                                                                       NaN
# Jurisdiction Names                                                            NaN
# Cancellation Policy                                                        strict
# Calculated host listings count                                                  4
# Reviews per Month                                                            5.92
# Geolocation                                          40.4284646414,-3.70392062465
# Features                        Host Is Superhost,Host Has Profile Pic,Host Id...
#
#                                                                             11226  \
# ID                                                                        7336831
# Listing Url                                  https://www.airbnb.com/rooms/7336831
# Scrape ID                                                          20170407214119
# Last Scraped                                                           2017-04-08
# Name                                            Chueca Penthouse Duplex w Terrace
# Summary                         4 available bedrooms, 2.5 bathrooms, 3 living ...
# Space                                                                         NaN
# Description                     4 available bedrooms, 2.5 bathrooms, 3 living ...
# Experiences Offered                                                          none
# Neighborhood Overview                                                         NaN
# Notes                                                                         NaN
# Transit                                                                       NaN
# Access                                                                        NaN
# Interaction                                                                   NaN
# House Rules                                                                   NaN
# Thumbnail Url                   https://a0.muscache.com/im/pictures/107733977/...
# Medium Url                      https://a0.muscache.com/im/pictures/107733977/...
# Picture Url                     https://public.opendatasoft.com/api/v2/catalog...
# XL Picture Url                  https://a0.muscache.com/im/pictures/107733977/...
# Host ID                                                                  38437353
# Host URL                               https://www.airbnb.com/users/show/38437353
# Host Name                                                                    Alex
# Host Since                                                             2015-07-14
# Host Location                                  Madrid, Community of Madrid, Spain
# Host About                      I´m a Brazilian married to an American, both l...
# Host Response Time                                                   within a day
# Host Response Rate                                                             73
# Host Acceptance Rate                                                          NaN
# Host Thumbnail Url              https://a0.muscache.com/im/users/38437353/prof...
# Host Picture Url                https://a0.muscache.com/im/users/38437353/prof...
# Host Neighbourhood                                                       Justicia
# Host Listings Count                                                             2
# Host Total Listings Count                                                       2
# Host Verifications                                      email,phone,reviews,jumio
# Street                          Justicia, Madrid, Comunidad de Madrid 28004, S...
# Neighbourhood                                                            Justicia
# Neighbourhood Cleansed                                                   Justicia
# Neighbourhood Group Cleansed                                               Centro
# City                                                                       Madrid
# State                                                         Comunidad de Madrid
# Zipcode                                                                     28004
# Market                                                                     Madrid
# Smart Location                                                      Madrid, Spain
# Country Code                                                                   ES
# Country                                                                     Spain
# Latitude                                                                  40.4214
# Longitude                                                                 -3.7006
# Property Type                                                     Bed & Breakfast
# Room Type                                                            Private room
# Accommodates                                                                    8
# Bathrooms                                                                     2.5
# Bedrooms                                                                        4
# Beds                                                                            5
# Bed Type                                                                 Real Bed
# Amenities                       Internet,Wireless Internet,Air conditioning,Wh...
# Square Feet                                                                   NaN
# Price                                                                          40
# Weekly Price                                                                  NaN
# Monthly Price                                                                 NaN
# Security Deposit                                                              100
# Cleaning Fee                                                                   20
# Guests Included                                                                 1
# Extra People                                                                   25
# Minimum Nights                                                                  2
# Maximum Nights                                                               1125
# Calendar Updated                                                      2 weeks ago
# Has Availability                                                              NaN
# Availability 30                                                                11
# Availability 60                                                                22
# Availability 90                                                                37
# Availability 365                                                              134
# Calendar last Scraped                                                  2017-04-08
# Number of Reviews                                                              11
# First Review                                                           2015-09-14
# Last Review                                                            2017-03-19
# Review Scores Rating                                                          100
# Review Scores Accuracy                                                         10
# Review Scores Cleanliness                                                      10
# Review Scores Checkin                                                          10
# Review Scores Communication                                                    10
# Review Scores Location                                                         10
# Review Scores Value                                                            10
# License                                                                       NaN
# Jurisdiction Names                                                            NaN
# Cancellation Policy                                                      moderate
# Calculated host listings count                                                  2
# Reviews per Month                                                            0.58
# Geolocation                                           40.4213854256,-3.7006021318
# Features                        Host Has Profile Pic,Host Identity Verified,Is...
#
#                                                                             10854  \
# ID                                                                        9835774
# Listing Url                                  https://www.airbnb.com/rooms/9835774
# Scrape ID                                                          20170315084710
# Last Scraped                                                           2017-03-15
# Name                              SON RIPOLL Country House w/ PRIVATE POOL - DEIA
# Summary                         Situated at the end of the winding road from D...
# Space                           This villa is only occupied during the low sea...
# Description                     Situated at the end of the winding road from D...
# Experiences Offered                                                          none
# Neighborhood Overview           Situated at the end of the winding road from D...
# Notes                           There's a private drive way into the estate wi...
# Transit                         From Palma airport take the motorway to Palma ...
# Access                          On the ground floor the entrance leads to a gr...
# Interaction                     Our representative in Deiá is Mya. Once you ma...
# House Rules                     PRESERVE OUR BEACHES (it is yours too). Don’t ...
# Thumbnail Url                                                                 NaN
# Medium Url                                                                    NaN
# Picture Url                     https://public.opendatasoft.com/api/v2/catalog...
# XL Picture Url                                                                NaN
# Host ID                                                                   4200246
# Host URL                                https://www.airbnb.com/users/show/4200246
# Host Name                                                     Pepe Pisos & Villas
# Host Since                                                             2012-11-20
# Host Location                          Palma de Mallorca, Balearic Islands, Spain
# Host About                      We are Rafael, Sammy, Lis, Karina, Valdete, As...
# Host Response Time                                                 within an hour
# Host Response Rate                                                             97
# Host Acceptance Rate                                                          NaN
# Host Thumbnail Url              https://a0.muscache.com/im/pictures/9906ec1b-0...
# Host Picture Url                https://a0.muscache.com/im/pictures/9906ec1b-0...
# Host Neighbourhood                                                        Palacio
# Host Listings Count                                                            68
# Host Total Listings Count                                                      68
# Host Verifications                             email,phone,facebook,reviews,jumio
# Street                                           Deià, Illes Balears 07179, Spain
# Neighbourhood                                                                 NaN
# Neighbourhood Cleansed                                                       Deyá
# Neighbourhood Group Cleansed                                                  NaN
# City                                                                         Deià
# State                                                               Illes Balears
# Zipcode                                                                     07179
# Market                                                            Mallorca Island
# Smart Location                                                        Deià, Spain
# Country Code                                                                   ES
# Country                                                                     Spain
# Latitude                                                                  39.7423
# Longitude                                                                 2.64415
# Property Type                                                               House
# Room Type                                                         Entire home/apt
# Accommodates                                                                    6
# Bathrooms                                                                       3
# Bedrooms                                                                        3
# Beds                                                                            3
# Bed Type                                                                 Real Bed
# Amenities                       TV,Cable TV,Internet,Wireless Internet,Air con...
# Square Feet                                                                   NaN
# Price                                                                         525
# Weekly Price                                                                  NaN
# Monthly Price                                                                 NaN
# Security Deposit                                                              500
# Cleaning Fee                                                                  NaN
# Guests Included                                                                 4
# Extra People                                                                  250
# Minimum Nights                                                                  1
# Maximum Nights                                                               1125
# Calendar Updated                                                       2 days ago
# Has Availability                                                              NaN
# Availability 30                                                                30
# Availability 60                                                                60
# Availability 90                                                                78
# Availability 365                                                              249
# Calendar last Scraped                                                  2017-03-15
# Number of Reviews                                                               0
# First Review                                                                  NaN
# Last Review                                                                   NaN
# Review Scores Rating                                                          NaN
# Review Scores Accuracy                                                        NaN
# Review Scores Cleanliness                                                     NaN
# Review Scores Checkin                                                         NaN
# Review Scores Communication                                                   NaN
# Review Scores Location                                                        NaN
# Review Scores Value                                                           NaN
# License                                                                       NaN
# Jurisdiction Names                                                            NaN
# Cancellation Policy                                               super_strict_60
# Calculated host listings count                                                 63
# Reviews per Month                                                             NaN
# Geolocation                                           39.7423085912,2.64414605034
# Features                        Host Has Profile Pic,Host Identity Verified,Is...
#
#                                                                             8254
# ID                                                                        1765529
# Listing Url                                  https://www.airbnb.com/rooms/1765529
# Scrape ID                                                          20170407214119
# Last Scraped                                                           2017-04-08
# Name                                              NICE APARTMENT IN MADRID CENTER
# Summary                         Functional apartment in the heart of Madrid, i...
# Space                                                          Wonderful location
# Description                     Functional apartment in the heart of Madrid, i...
# Experiences Offered                                                          none
# Neighborhood Overview           Very quite place in the midle of Madrid but wi...
# Notes                                                                     No lift
# Transit                         This place have a very good service of taxis, ...
# Access                          TV, hairdryer,iron , hot water, boiler, Oven S...
# Interaction                     No dudes en llamarnos si tienes cualquier duda...
# House Rules                     just trate the house like your own house, than...
# Thumbnail Url                                                                 NaN
# Medium Url                                                                    NaN
# Picture Url                     https://public.opendatasoft.com/api/v2/catalog...
# XL Picture Url                                                                NaN
# Host ID                                                                   9277975
# Host URL                                https://www.airbnb.com/users/show/9277975
# Host Name                                                                    Raul
# Host Since                                                             2013-10-07
# Host Location                                Alcorcón, Comunidad de Madrid, Spain
# Host About                      Soy de Madrid, junto con mi novia nos encanta ...
# Host Response Time                                                 within an hour
# Host Response Rate                                                            100
# Host Acceptance Rate                                                          NaN
# Host Thumbnail Url              https://a0.muscache.com/im/users/9277975/profi...
# Host Picture Url                https://a0.muscache.com/im/users/9277975/profi...
# Host Neighbourhood                                                            NaN
# Host Listings Count                                                             1
# Host Total Listings Count                                                       1
# Host Verifications                                 email,phone,reviews,work_email
# Street                                   Madrid, Community of Madrid 28005, Spain
# Neighbourhood                                                                 NaN
# Neighbourhood Cleansed                                                    Palacio
# Neighbourhood Group Cleansed                                               Centro
# City                                                                       Madrid
# State                                                         Community of Madrid
# Zipcode                                                                     28005
# Market                                                                     Madrid
# Smart Location                                                      Madrid, Spain
# Country Code                                                                   ES
# Country                                                                     Spain
# Latitude                                                                   40.411
# Longitude                                                                -3.71118
# Property Type                                                           Apartment
# Room Type                                                         Entire home/apt
# Accommodates                                                                    3
# Bathrooms                                                                       1
# Bedrooms                                                                        1
# Beds                                                                            2
# Bed Type                                                                 Real Bed
# Amenities                       TV,Internet,Wireless Internet,Kitchen,Smoking ...
# Square Feet                                                                   NaN
# Price                                                                          52
# Weekly Price                                                                  315
# Monthly Price                                                                 990
# Security Deposit                                                              100
# Cleaning Fee                                                                   20
# Guests Included                                                                 2
# Extra People                                                                   15
# Minimum Nights                                                                  2
# Maximum Nights                                                               1125
# Calendar Updated                                                      3 weeks ago
# Has Availability                                                              NaN
# Availability 30                                                                 0
# Availability 60                                                                 0
# Availability 90                                                                 6
# Availability 365                                                              281
# Calendar last Scraped                                                  2017-04-08
# Number of Reviews                                                              40
# First Review                                                           2014-04-07
# Last Review                                                            2017-03-24
# Review Scores Rating                                                           94
# Review Scores Accuracy                                                          9
# Review Scores Cleanliness                                                      10
# Review Scores Checkin                                                          10
# Review Scores Communication                                                    10
# Review Scores Location                                                         10
# Review Scores Value                                                            10
# License                                                                       NaN
# Jurisdiction Names                                                            NaN
# Cancellation Policy                                                      moderate
# Calculated host listings count                                                  1
# Reviews per Month                                                            1.09
# Geolocation                                          40.4109587612,-3.71118059484
# Features                                    Host Has Profile Pic,Requires License

# %% [markdown]
# ### Toma de contacto con las variables

# %% [markdown]
# Eliminamos las columnas que no nos aportan información a primera vista. Están agrupados en las siguientes listas:
# - non_informative -->
# - urls -->
# - text -->
# - non_relevant_dates -->
# - delete -->
# - host_info -->

# %%
non_informative = ['ID', 'Scrape ID', 'Last Scraped', 'Name']

urls = ['Listing Url','Thumbnail Url', 'Medium Url','Picture Url', 'XL Picture Url',
       'Host URL','Host Thumbnail Url', 'Host Picture Url']

text = ['Summary', 'Space','Description','Neighborhood Overview', 'Notes','Transit','Access',
        'Interaction','House Rules','Host About']

non_relevant_dates = ['Calendar Updated', 'Calendar last Scraped', 'First Review', 'Last Review']

delete = ['Weekly Price', 'Monthly Price'] #pq queremos predecir 'price'

host_info = ['Host ID','Host Name','Host Location','Host Neighbourhood','Calculated host listings count',
             'Host Listings Count', 'Host Total Listings Count']

# %%
data.drop(non_informative, axis = 1, inplace = True)
data.drop(urls, axis = 1, inplace = True)
data.drop(text, axis = 1, inplace = True)
data.drop(non_relevant_dates, axis = 1, inplace = True)
data.drop(delete, axis = 1, inplace = True)
data.drop(host_info, axis = 1, inplace = True)

# %% [markdown]
# ### Visualización de la distribución de la variable objetivo:

# %%
plt.subplots(nrows=1,ncols=2,figsize=(20,5))

plt.subplot(1,2,1)
sns.set_theme(style="whitegrid")
sns.boxplot(data=data, y='Price', saturation = 0.6, linewidth = 1, color = '#E55D5D')
plt.subplot(1,2,2)
sns.set_theme(style="whitegrid")
sns.histplot(data['Price'],color = '#E55D5D', bins = 20,kde = True, stat='density')
# Out:
# <AxesSubplot:xlabel='Price', ylabel='Density'>

# %% [markdown]
# Un precio mayor de 200 se considera outlier. Por lo que vamos a hacer un filtrado y eliminaremos todos los apartamentos con precio mayor a 200.

# %%
print(len(data[data['Price']>200]))
# Out:
# 387

# %%
data = data[data['Price']<200]

# %% [markdown]
# ### Análisis de cada variable:

# %%
data.head(3)
# Out:
#       Experiences Offered  Host Since Host Response Time  Host Response Rate  \
# 9937                 none  2010-01-19     within an hour               100.0
# 10483                none  2014-04-09     within an hour                98.0
# 11226                none  2015-07-14       within a day                73.0
#
#        Host Acceptance Rate            Host Verifications  \
# 9937                    NaN  email,phone,facebook,reviews
# 10483                   NaN     email,phone,reviews,jumio
# 11226                   NaN     email,phone,reviews,jumio
#
#                                                   Street Neighbourhood  \
# 9937   Justicia, Madrid, Comunidad de Madrid 28004, S...      Justicia
# 10483  Justicia, Madrid, Comunidad de Madrid 28004, S...      Justicia
# 11226  Justicia, Madrid, Comunidad de Madrid 28004, S...      Justicia
#
#       Neighbourhood Cleansed Neighbourhood Group Cleansed    City  \
# 9937                Justicia                       Centro  Madrid
# 10483            Universidad                       Centro  Madrid
# 11226               Justicia                       Centro  Madrid
#
#                      State Zipcode  Market Smart Location Country Code  \
# 9937   Comunidad de Madrid   28004  Madrid  Madrid, Spain           ES
# 10483  Comunidad de Madrid   28004  Madrid  Madrid, Spain           ES
# 11226  Comunidad de Madrid   28004  Madrid  Madrid, Spain           ES
#
#       Country   Latitude  Longitude    Property Type        Room Type  \
# 9937    Spain  40.424715  -3.698638        Apartment  Entire home/apt
# 10483   Spain  40.428465  -3.703921        Apartment  Entire home/apt
# 11226   Spain  40.421385  -3.700602  Bed & Breakfast     Private room
#
#        Accommodates  Bathrooms  Bedrooms  Beds       Bed Type  \
# 9937              2        1.0       0.0   1.0  Pull-out Sofa
# 10483             4        1.0       1.0   1.0       Real Bed
# 11226             8        2.5       4.0   5.0       Real Bed
#
#                                                Amenities  Square Feet  Price  \
# 9937   TV,Wireless Internet,Air conditioning,Kitchen,...          0.0   49.0
# 10483  TV,Internet,Wireless Internet,Air conditioning...          NaN  105.0
# 11226  Internet,Wireless Internet,Air conditioning,Wh...          NaN   40.0
#
#        Security Deposit  Cleaning Fee  Guests Included  Extra People  \
# 9937              100.0          30.0                1             0
# 10483              88.0          29.0                2            15
# 11226             100.0          20.0                1            25
#
#        Minimum Nights  Maximum Nights  Has Availability  Availability 30  \
# 9937               28            1825               NaN                0
# 10483               1              62               NaN               13
# 11226               2            1125               NaN               11
#
#        Availability 60  Availability 90  Availability 365  Number of Reviews  \
# 9937                 0                0                99                 35
# 10483               30               49               324                214
# 11226               22               37               134                 11
#
#        Review Scores Rating  Review Scores Accuracy  \
# 9937                   89.0                     9.0
# 10483                  97.0                    10.0
# 11226                 100.0                    10.0
#
#        Review Scores Cleanliness  Review Scores Checkin  \
# 9937                         9.0                    9.0
# 10483                       10.0                   10.0
# 11226                       10.0                   10.0
#
#        Review Scores Communication  Review Scores Location  \
# 9937                          10.0                    10.0
# 10483                         10.0                    10.0
# 11226                         10.0                    10.0
#
#        Review Scores Value License  Jurisdiction Names Cancellation Policy  \
# 9937                   9.0     NaN                 NaN              strict
# 10483                 10.0     NaN                 NaN              strict
# 11226                 10.0     NaN                 NaN            moderate
#
#        Reviews per Month                   Geolocation  \
# 9937                0.42  40.4247153175,-3.69863818771
# 10483               5.92  40.4284646414,-3.70392062465
# 11226               0.58   40.4213854256,-3.7006021318
#
#                                                 Features
# 9937   Host Has Profile Pic,Is Location Exact,Require...
# 10483  Host Is Superhost,Host Has Profile Pic,Host Id...
# 11226  Host Has Profile Pic,Host Identity Verified,Is...

# %% [markdown]
# <br>

# %% [markdown]
# Viendo el head de la data, sorprende los muchos 'none' que hay en la variable "Experiences Offered" asique analizamos cuantas veces está presente cada valor:

# %%
data['Experiences Offered'].value_counts()
# Out:
# none    10039
# Name: Experiences Offered, dtype: int64

# %%
ratio = data['Experiences Offered'].value_counts()[0]/len(data['Experiences Offered'])
print(f"Ratio de veces que aparece 'none' en el dataset: {np.round(ratio,4)*100}%")
# Out:
# Ratio de veces que aparece 'none' en el dataset: 100.0%

# %% [markdown]
# Esta variable tiene un 100% de instancias con el mismo valor, es decir tiene valor constante y por lo tanto que no aporta información a la hora de predecir

# %%
data.drop('Experiences Offered', axis = 1, inplace = True)

# %% [markdown]
# <br>

# %% [markdown]
# Geolocation contiene la misma info que longitude y latitude:

# %%
data[['Latitude', 'Longitude', 'Geolocation']].head(3)
# Out:
#         Latitude  Longitude                   Geolocation
# 9937   40.424715  -3.698638  40.4247153175,-3.69863818771
# 10483  40.428465  -3.703921  40.4284646414,-3.70392062465
# 11226  40.421385  -3.700602   40.4213854256,-3.7006021318

# %%
data.drop('Geolocation', axis = 1, inplace = True)

# %% [markdown]
# <br>

# %% [markdown]
# Analizamos las variables que hacen referencia a la **localización del piso**

# %%
cols_location = ['Street', 'Neighbourhood','Neighbourhood Cleansed', 'Neighbourhood Group Cleansed', 
                 'City','State', 'Zipcode', 'Market', 'Smart Location', 'Country Code','Country']

# %%
#data['City'].value_counts()
ratio = np.round((data['City'].value_counts()['Madrid']/data.shape[0])*100,2)
print(f"Ratio de valores en 'City' que son 'Madrid':\t{ratio}% ")
# Out:
# Ratio de valores en 'City' que son 'Madrid':	95.89%

# %% [markdown]
# Eliminamos todo lo que no sea Madrid

# %%
print(f"Eliminamos: {len(data[data['City']!='Madrid'])} instancias")
print(f"Que representa el {np.round((len(data[data['City']!='Madrid'])/data.shape[0])*100,2)}% de instancias")
# Out:
# Eliminamos: 413 instancias
# Que representa el 4.11% de instancias

# %% [markdown]
# Parece un porcentaje elevado, pero de esta forma nos centramos en predecir para la ciudad de Madrid y tratar de maximizar la accuracy con las características concretas de esta ciudad. Ya que del resto de ciudades y paises tenemos muchas menos instancias y al cambiar las condiciones puede verse afectada la predicción del precio.

# %%
data.drop(data[data['City']!='Madrid'].index, inplace = True)

# %%
print(f"Tenemos: {data.shape[0]} filas")
# Out:
# Tenemos: 9626 filas

# %% [markdown]
# Al hacer este filtro para solo aceptar instancias de Madrid algunas columnas pueden convertirse en constantes, vamos a ver cuáles:

# %%
data[cols_location].apply(lambda col: len(col.unique()))
# Out:
# Street                          594
# Neighbourhood                    66
# Neighbourhood Cleansed          125
# Neighbourhood Group Cleansed     21
# City                              1
# State                            15
# Zipcode                          69
# Market                            5
# Smart Location                    2
# Country Code                      1
# Country                           1
# dtype: int64

# %% [markdown]
# Vemos que "City", "Country Code" y "Country" permanecen constantes. Esto significa que no aportan nada a la predicción y por lo tanto las eliminamos:

# %%
cols_location = set(cols_location) - set(['City','Country Code','Country'])
print("Columnas de location que nos quedan: \n",cols_location)
data.drop(['City','Country Code','Country'],axis = 1, inplace = True)
# Out:
# Columnas de location que nos quedan:
#  {'Zipcode', 'Market', 'Neighbourhood', 'Smart Location', 'Neighbourhood Cleansed', 'Street', 'Neighbourhood Group Cleansed', 'State'}

# %% [markdown]
# Nos sorprende "Smart Location" y "Market", por lo que vamos a hacer una exploración de estas columnas:

# %%
print(data['Smart Location'].value_counts())
# Out:
# Madrid, Spain     9617
# Madrid , Spain       9
# Name: Smart Location, dtype: int64

# %% [markdown]
# Vemos que realmente el valor es constante, lo unico que lo detecta como dos distintos por un espacio de diferencia

# %%
#print(data['Market'].value_counts())
print(np.round((data['Market'].value_counts()*100)/data.shape[0],2))
# Out:
# Madrid                   99.50
# Other (International)     0.08
# Toledo                    0.01
# London                    0.01
# Name: Market, dtype: float64

# %% [markdown]
# Vemos que el 99.53% de los valores en la columna "Market" son "Madrid" asique consideramos esta columna como constante y la eliminamos.

# %%
cols_location = set(cols_location) - set(['Smart Location','Market'])
print("Columnas de location que nos quedan: \n",cols_location)
data.drop(['Smart Location','Market'],axis = 1, inplace = True)
# Out:
# Columnas de location que nos quedan:
#  {'Zipcode', 'Neighbourhood', 'Neighbourhood Cleansed', 'Street', 'Neighbourhood Group Cleansed', 'State'}

# %% [markdown]
# Al centrarnos solo en la ciudad de Madrid, sorprende que "State" tenga 15 valores distintos por lo que vamos a hacer una exploración de los valores de esta variable:

# %%
data['State'].value_counts()
# Out:
# Comunidad de Madrid             7727
# Community of Madrid             1388
# Madrid                           462
# Spain                              4
# España                             3
# Communauté de Madrid               3
# 28                                 2
# España,Madrid                      1
# Espańa                             1
# MADRID                             1
# Madrid capital                     1
# madrid                             1
# Usera                              1
# Autonome Gemeinschaft Madrid       1
# Name: State, dtype: int64

# %% [markdown]
# Vemos que realmente todos son "Madrid" pero escrito de distintas formas o haciendo referencia al país (España) que ya teníamos en otra columna y hemos eliminado.
# <br> Por esto, volvemos a considerar esta columna constante y nos deshacemos de ella.

# %%
cols_location = set(cols_location) - set(['State'])
print("Columnas de location que nos quedan: \n",cols_location)
data.drop(['State'],axis = 1, inplace = True)
# Out:
# Columnas de location que nos quedan:
#  {'Zipcode', 'Neighbourhood', 'Neighbourhood Cleansed', 'Street', 'Neighbourhood Group Cleansed'}

# %% [markdown]
# <br>

# %%
data[cols_location]
# Out:
#       Zipcode Neighbourhood Neighbourhood Cleansed  \
# 9937    28004      Justicia               Justicia
# 10483   28004      Justicia            Universidad
# 11226   28004      Justicia               Justicia
# 8254    28005           NaN                Palacio
# 2559    28005           NaN                Palacio
# ...       ...           ...                    ...
# 5191    28005     La Latina                Palacio
# 13418   28038           NaN               Numancia
# 5390      NaN           NaN                 Cortes
# 860     28026           NaN            Almendrales
# 7270    28012     La Latina            Embajadores
#
#                                                   Street  \
# 9937   Justicia, Madrid, Comunidad de Madrid 28004, S...
# 10483  Justicia, Madrid, Comunidad de Madrid 28004, S...
# 11226  Justicia, Madrid, Comunidad de Madrid 28004, S...
# 8254            Madrid, Community of Madrid 28005, Spain
# 2559            Madrid, Community of Madrid 28005, Spain
# ...                                                  ...
# 5191   La Latina, Madrid, Comunidad de Madrid 28005, ...
# 13418           Madrid, Comunidad de Madrid 28038, Spain
# 5390                  Madrid, Comunidad de Madrid, Spain
# 860             Madrid, Comunidad de Madrid 28026, Spain
# 7270   La Latina, Madrid, Comunidad de Madrid 28012, ...
#
#       Neighbourhood Group Cleansed
# 9937                        Centro
# 10483                       Centro
# 11226                       Centro
# 8254                        Centro
# 2559                        Centro
# ...                            ...
# 5191                        Centro
# 13418           Puente de Vallecas
# 5390                        Centro
# 860                          Usera
# 7270                        Centro
#
# [9626 rows x 5 columns]

# %% [markdown]
# Vemos que la variable "street" no aporta información, ya que incluye lo que ya tenemos en otras columnas. Por lo que vamos a eliminarla también:

# %%
cols_location = set(cols_location) - set(['Street'])
print("Columnas de location que nos quedan: \n",cols_location)
data.drop(['Street'],axis = 1, inplace = True)
# Out:
# Columnas de location que nos quedan:
#  {'Neighbourhood', 'Zipcode', 'Neighbourhood Group Cleansed', 'Neighbourhood Cleansed'}

# %% [markdown]
# <br>

# %% [markdown]
# Ahora vamos a analizar la relación entre las tres variables:
# <br>Neighbourhood
# <br>Neighbourhood Cleansed
# <br>Neighbourhood Group Cleansed

# %%
df = data[cols_location - set(['Zipcode'])]
df.head(5)
# Out:
#       Neighbourhood Neighbourhood Group Cleansed Neighbourhood Cleansed
# 9937       Justicia                       Centro               Justicia
# 10483      Justicia                       Centro            Universidad
# 11226      Justicia                       Centro               Justicia
# 8254            NaN                       Centro                Palacio
# 2559            NaN                       Centro                Palacio

# %%
df.isnull().sum()
# Out:
# Neighbourhood                   3267
# Neighbourhood Group Cleansed       0
# Neighbourhood Cleansed             0
# dtype: int64

# %% [markdown]
# ¿Con cuál nos quedamos?
# <br> Está claro que con Neighbourhood no, ya que tiene muchos nulos.
# <br> Por lo que tenemos dos opciones:
# - Neighbourhood Group Cleansed
# - Neighbourhood Cleansed

# %%
df.apply(lambda col: len(col.unique()))
# Out:
# Neighbourhood                    66
# Neighbourhood Group Cleansed     21
# Neighbourhood Cleansed          125
# dtype: int64

# %% [markdown]
# Vemos que Neighbourhood Group Cleansed es mucho más robusto ya que tiene menos variedad de valores, por lo que nos vamos a quedar con ella.

# %%
data.drop(['Neighbourhood', 'Neighbourhood Cleansed'],axis = 1, inplace = True)

# %% [markdown]
# <br>

# %% [markdown]
# Vamos a mirar la relación Neighbourhood Group Cleansed y Zipcode:

# %%
print(data.Zipcode.unique())
print(f" \nHay {data.Zipcode.isnull().sum()} valores nan.")
#print(df.Zipcode.value_counts())
# Out:
# ['28004' '28005' '28045' '28028' '28012' '28020' '28013' '28015' '28014'
#  '28009' '28007' '28039' '28003' '28026' nan '28011' '28001' '28053'
#  '28041' '28042' '28002' '28022' '28049' '28025' '28016' '28008' '28029'
#  '28006' '28010' '28037' '28046' '28019' '28033' '28030' '28018' '28043'
#  '28024' '28047' '28051' '28035' '28031' '28017' '28027' '28023' '28032'
#  '28044' '28021' '28036' '28050' '2015' '28040' '28038' '28105' '28055'
#  '28034' 'Madrid 28004' '28056' '28002\n28002' '27013' '2815' '28' '28094'
#  '28060' '2805' '28054' '28052' '28051\n28051' '28048' '25008']
#
# Hay 328 valores nan.

# %% [markdown]
# Con este primer vistazo vemos que hay bastantes errores: '28051\n28051' ,'-', 'Madrid 28004','2804'...
# <br>Y hay 361 NaNs

# %%
df = data[['Neighbourhood Group Cleansed', 'Zipcode']]

grouped = df.groupby(['Neighbourhood Group Cleansed'])
for neigh in grouped.groups.keys():
    print(f"\nFor neighbourhood: {neigh} the zipcodes are: " )
    d = grouped.get_group(neigh)
    print(d['Zipcode'].value_counts())
# Out:
# For neighbourhood: Arganzuela the zipcodes are:
# 28045    369
# 28005    156
# 28012     43
# 28019      3
# 28047      1
# 28007      1
# 28014      1
# Name: Zipcode, dtype: int64
#
# For neighbourhood: Barajas the zipcodes are:
# 28042    57
# 28055     1
# Name: Zipcode, dtype: int64
#
# For neighbourhood: Carabanchel the zipcodes are:
# 28019    136
# 28025     92
# 28044      8
# 28054      7
# 28047      7
# 28005      1
# Name: Zipcode, dtype: int64
#
# For neighbourhood: Centro the zipcodes are:
# 28012           1478
# 28004           1264
# 28013            741
# 28005            704
# 28014            387
# 28015            202
# 28008             16
# 28045              2
# 28001              2
# 28011              1
# 25008              1
# 2805               1
# 28034              1
# 28033              1
# 28094              1
# 28018              1
# Madrid 28004       1
# 28010              1
# 28007              1
# 2015               1
# 28003              1
# 27013              1
# 28056              1
# Name: Zipcode, dtype: int64
#
# For neighbourhood: Chamartín the zipcodes are:
# 28002           121
# 28036            49
# 28016            49
# 28046            11
# 28006            11
# 28002\n28002      1
# 28020             1
# Name: Zipcode, dtype: int64
#
# For neighbourhood: Chamberí the zipcodes are:
# 28010    267
# 28015    235
# 28003    122
# 28004     24
# 28008      4
# 2815       1
# 28014      1
# 28013      1
# 28046      1
# 28105      1
# 28012      1
# Name: Zipcode, dtype: int64
#
# For neighbourhood: Ciudad Lineal the zipcodes are:
# 28017    78
# 28027    75
# 28043    29
# 28033    22
# 28        1
# 28007     1
# Name: Zipcode, dtype: int64
#
# For neighbourhood: Fuencarral - El Pardo the zipcodes are:
# 28035    30
# 28034    29
# 28029    22
# 28050    13
# 28049     2
# Name: Zipcode, dtype: int64
#
# For neighbourhood: Hortaleza the zipcodes are:
# 28043    51
# 28033    38
# 28050    30
# 28055     9
# 28042     6
# Name: Zipcode, dtype: int64
#
# For neighbourhood: Latina the zipcodes are:
# 28011    191
# 28047     34
# 28024     30
# 28044      6
# 28005      2
# 28013      2
# 28025      2
# 28054      1
# 28019      1
# Name: Zipcode, dtype: int64
#
# For neighbourhood: Moncloa - Aravaca the zipcodes are:
# 28008    234
# 28023     15
# 28035     14
# 28040     13
# 28039      8
# 28015      6
# 28011      5
# 28003      4
# 28013      3
# 28004      1
# 28024      1
# Name: Zipcode, dtype: int64
#
# For neighbourhood: Moratalaz the zipcodes are:
# 28030    53
# Name: Zipcode, dtype: int64
#
# For neighbourhood: Puente de Vallecas the zipcodes are:
# 28053    69
# 28038    55
# 28018    33
# 28048     1
# 28031     1
# Name: Zipcode, dtype: int64
#
# For neighbourhood: Retiro the zipcodes are:
# 28007    143
# 28009     74
# 28014     60
# 28045      1
# 28053      1
# 28028      1
# 28004      1
# Name: Zipcode, dtype: int64
#
# For neighbourhood: Salamanca the zipcodes are:
# 28028    189
# 28006    144
# 28001    142
# 28009     88
# 28014      4
# 28027      1
# 28004      1
# 28007      1
# 28005      1
# 28020      1
# 28002      1
# Name: Zipcode, dtype: int64
#
# For neighbourhood: San Blas - Canillejas the zipcodes are:
# 28037    50
# 28022    26
# 28027     9
# 28032     4
# 28042     1
# Name: Zipcode, dtype: int64
#
# For neighbourhood: Tetuán the zipcodes are:
# 28020    141
# 28039    111
# 28029     54
# 28046      8
# 28003      3
# 28040      1
# 28036      1
# 28060      1
# Name: Zipcode, dtype: int64
#
# For neighbourhood: Usera the zipcodes are:
# 28026    68
# 28041    34
# 28019     2
# Name: Zipcode, dtype: int64
#
# For neighbourhood: Vicálvaro the zipcodes are:
# 28032    22
# 28031     1
# 28052     1
# Name: Zipcode, dtype: int64
#
# For neighbourhood: Villa de Vallecas the zipcodes are:
# 28031           19
# 28051           15
# 28038            1
# 28051\n28051     1
# Name: Zipcode, dtype: int64
#
# For neighbourhood: Villaverde the zipcodes are:
# 28021    40
# 28041    15
# Name: Zipcode, dtype: int64

# %%
print(f"El porcentaje de nulos es {np.round((data.Zipcode.isnull().sum()/data.shape[0])*100,2)}%")
#data.dropna(subset=['Zipcode'], inplace = True)
# Out:
# El porcentaje de nulos es 3.41%

# %%
data.Zipcode.unique()
# Out:
# array(['28004', '28005', '28045', '28028', '28012', '28020', '28013',
#        '28015', '28014', '28009', '28007', '28039', '28003', '28026', nan,
#        '28011', '28001', '28053', '28041', '28042', '28002', '28022',
#        '28049', '28025', '28016', '28008', '28029', '28006', '28010',
#        '28037', '28046', '28019', '28033', '28030', '28018', '28043',
#        '28024', '28047', '28051', '28035', '28031', '28017', '28027',
#        '28023', '28032', '28044', '28021', '28036', '28050', '2015',
#        '28040', '28038', '28105', '28055', '28034', 'Madrid 28004',
#        '28056', '28002\n28002', '27013', '2815', '28', '28094', '28060',
#        '2805', '28054', '28052', '28051\n28051', '28048', '25008'],
#       dtype=object)

# %% [markdown]
# La corrección de los errores detectados son:
#
# - 25008, 20013 --> drop
# - 27013, 27004 --> drop
# - 28850 --> drop
# - '-' --> drop
#
# - Madrid 28004 --> 28004
# - 2804 --> 28004
#
# - 28002\n28002 --> 28002
# - 28051\n28051 --> 28051
#
# - 2815 --> 28015
# - 2015 --> 28015

# %% [markdown]
# Antes de hacer los drops, comprobamos que son pocos valores:
# <br> En caso de que sean muchos, igual tenemos que replantearnos hacer todo este procesado y limitarnos a hacer drop de la columna, ya que antes con los nan ya nos hemos cargaríamos un 3% de la data.

# %%
#data.Zipcode.value_counts()

# %%
#data.drop(data[data['Zipcode']=='-'].index, inplace = True)
#data.drop(data[data['Zipcode']=='25008'].index, inplace = True)
#data.drop(data[data['Zipcode']=='20013'].index, inplace = True)
#data.drop(data[data['Zipcode']=='27013'].index, inplace = True)
#data.drop(data[data['Zipcode']=='27004'].index, inplace = True)
#data.drop(data[data['Zipcode']=='28850'].index, inplace = True)
#data['Zipcode'] = data['Zipcode'].replace('Madrid 28004','28004')
#data['Zipcode'] = data['Zipcode'].replace('2804','28004')
#data['Zipcode'] = data['Zipcode'].replace('28002\n28002','28002')
#data['Zipcode'] = data['Zipcode'].replace('28051\n28051','28051')
#data['Zipcode'] = data['Zipcode'].replace('2815','28015')
#data['Zipcode'] = data['Zipcode'].replace('2015','28015')'''

# %% [markdown]
# **Problemas con esta variable:**<br>
# - Es una variable con bastante error --> estos errores se tienen que estudiar manualmente ya que son errores a la hora de que el usuario escribe y se equivoca cambiando o omitiendo un número. <br> Además, en un vistazo así rápido vemos que hay algún barrio con Zipcode que no le corresponde. Por ejemplo: <br> Haciendo una búsqueda en internet vemos que los zipcodes que le corresponden a Chamartín son: 28002,28006,28016,28036,28046. Y en el dataset nos encontramos con que además de esos hay valores de zipcode: 28010,28003,28002,28020.
# - Eliminar aquellas columnas que tienen nan ya nos quita un 3% de instancias.
# - El hecho de que el error tengamos que estudiarlo manualmente hace que para el conjunto de test haya que automatizar esta limpieza de alguna forma, no tan directa. Ya que de forma sencilla podríamos hacer drop de todas aquellas instancias que tengan valor de zipcode que empiece distinto de 28, pero igualmente seguiríamos teniendo error y perderíamos bastante instancias
# - Además al ser una variable categórica luego habría que transformarla y no es una transformación directa convirtiéndolo a entero porque eso haría entender al algoritmo que el código 28051 es más importante que 28002.

# %% [markdown]
# Por todos estos motivos, y aunque de primeras había planteado mantener esta variable, finalmente voy a dropearla por comodidad en la práctica.

# %%
data.drop(['Zipcode'],axis = 1, inplace = True)

# %% [markdown]
# <br>

# %% [markdown]
# Finalmente, después de esta primera limpieza, nos quedamos con variable de localización del apartamento con "Neighbourhood Group Cleansed". Además hemos hecho un filtrado quedandonos solo con la data de los apartamentos en Madrid.

# %% [markdown]
# Vamos a analizar la cantidad de valores nulos que tiene cada columna y aquellas que tienen más de un 25% de nulos las eliminaremos, ya que se considera que el procentaje de datos que tenemos puede no ser representativo para rellenar los nans

# %%
print("Columnas con más de 25% de nulls entre sus instancias:\n")

drop_cols = []
for col in data.columns:
    percentage = np.round(data[col].isnull().sum()/data.shape[0]*100,2)
    if percentage >= 25:
        print(f"{col:<35}{percentage}%")
        drop_cols.append(col)
        
print("Las cols a dropear son:", drop_cols)
# Out:
# Columnas con más de 25% de nulls entre sus instancias:
#
# Host Acceptance Rate               100.0%
# Square Feet                        95.98%
# Security Deposit                   57.31%
# Cleaning Fee                       40.98%
# Has Availability                   100.0%
# License                            98.13%
# Jurisdiction Names                 100.0%
# Las cols a dropear son: ['Host Acceptance Rate', 'Square Feet', 'Security Deposit', 'Cleaning Fee', 'Has Availability', 'License', 'Jurisdiction Names']

# %%
data.drop(drop_cols, axis = 1, inplace = True)

# %%
print(f"Ahora tenemos: {data.shape[1]} variables")
# Out:
# Ahora tenemos: 35 variables

# %% [markdown]
# <br>

# %% [markdown]
# **Variables:** <br>AMENITIES -- FEATURES -- HOST VERIFICATIONS

# %%
print(data['Amenities'].isnull().sum())
print(data['Features'].isnull().sum())
print(data['Host Verifications'].isnull().sum())
# Out:
# 70
# 0
# 5

# %%
#Para comprobar que los nulos se cambian bien
i = data[data['Amenities'].isnull()].index
print(data.loc[i[0],'Amenities'])
# Out:
# nan

# %%
data['Features'] = data['Features'].apply(lambda x: len(str(x).split(',')))

data['Amenities'].fillna(0, inplace = True)
data['Amenities'] = data['Amenities'].apply(lambda x: len(str(x).split(',')) if x!=0 else 0)

data['Host Verifications'].fillna(0, inplace = True)
data['Host Verifications'] = data['Host Verifications'].apply(lambda x: len(str(x).split(',')) if x!=0 else 0)

# %%
#Para comprobar que los nulos se cambian bien por valor 0
print(data.loc[i[0],'Amenities'])
# Out:
# 0

# %% [markdown]
# <br>

# %% [markdown]
# Hemos reducido bastante la dimensionalidad del problema. Pero aún tenemos cosas que hacer:
# - Análisis de posibles nuevas features
# - Analizar las correlaciones entre variables
# - Rellenar campos vacíos
# - Transformar las variables categóricas a numéricas

# %%
print(f"Tenemos: {data.shape[0]} filas")
# Out:
# Tenemos: 9626 filas

# %%
data.columns
# Out:
# Index(['Host Since', 'Host Response Time', 'Host Response Rate',
#        'Host Verifications', 'Neighbourhood Group Cleansed', 'Latitude',
#        'Longitude', 'Property Type', 'Room Type', 'Accommodates', 'Bathrooms',
#        'Bedrooms', 'Beds', 'Bed Type', 'Amenities', 'Price', 'Guests Included',
#        'Extra People', 'Minimum Nights', 'Maximum Nights', 'Availability 30',
#        'Availability 60', 'Availability 90', 'Availability 365',
#        'Number of Reviews', 'Review Scores Rating', 'Review Scores Accuracy',
#        'Review Scores Cleanliness', 'Review Scores Checkin',
#        'Review Scores Communication', 'Review Scores Location',
#        'Review Scores Value', 'Cancellation Policy', 'Reviews per Month',
#        'Features'],
#       dtype='object')

# %% [markdown]
# <br>

# %% [markdown]
# ### Posibles nuevas features:

# %% [markdown]
# Como hicimos en la teoría con el dataset de house_data:

# %%
#Para tener un ratio entre camas y baños:
data['bed_bath_rooms']   = data['Bedrooms']*data['Bathrooms']

# %% [markdown]
# <br>

# %% [markdown]
# ### Análisis de la correlación entre variables numéricas:

# %%
# Compute the correlation matrix
corr = np.abs(data.drop(['Price'], axis=1).corr())
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(12, 10))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask,vmin = 0.0, vmax=1.0, center=0.5,
            linewidths=.1, cmap="YlGnBu", cbar_kws={"shrink": .8})

plt.show()

# %% [markdown]
# Observamos lo siguiente:
# - Alta correlación de la variable accomodates con beds y bedsrooms. Estas dos últimas variables también tienen una correlación significativa. Todo esto es acorde a lo que nos esperamos (cuántas más haitaciones, más camas). <br>De estas variables vamos a eliminar "Beds" porque es la que menos correlación tiene con la objetivo.

# %%
print(data['Accommodates'].corr(data['Price']))
print(data['Bedrooms'].corr(data['Price']))
print(data['Beds'].corr(data['Price']))
# Out:
# 0.624009626334199
# 0.4645160717969051
# 0.45121907141802875

# %%
data.drop('Beds', axis = 1, inplace = True)

# %% [markdown]
# <br>

# %% [markdown]
# - Muy alta correlacón en las variables de availability. <br> Borramos todas y mantenemos la de "Availability 365" porque es la que mayor correlación tiene con la varaible objetivo "Price"

# %%
print(np.abs(data['Availability 30'].corr(data['Price'])))
print(np.abs(data['Availability 60'].corr(data['Price'])))
print(np.abs(data['Availability 90'].corr(data['Price'])))
print(np.abs(data['Availability 365'].corr(data['Price'])))
# Out:
# 0.06565435134513195
# 0.06419637764477731
# 0.0714550617014911
# 0.08427541008398662

# %%
data.drop(['Availability 30','Availability 60','Availability 90'], axis = 1, inplace = True)

# %% [markdown]
# <br>

# %% [markdown]
# - Alta correlación de la variables adicional que hemos creado "bed_bath_rooms" con "bathrooms" y "bedrooms" pero esto entra dentro de lo que esperabamos ya que se ha creado a partir de ellas. <br> De momento la mantenemos y analizaremos como se comporta el modelo para analizar si ha sido o no una buena idea mantenerla.

# %% [markdown]
# <br>

# %% [markdown]
# - Vemos también alta correlación en el grupo de variables de reviews:

# %%
data.columns[data.columns.str.startswith("Review")]
# Out:
# Index(['Review Scores Rating', 'Review Scores Accuracy',
#        'Review Scores Cleanliness', 'Review Scores Checkin',
#        'Review Scores Communication', 'Review Scores Location',
#        'Review Scores Value', 'Reviews per Month'],
#       dtype='object')

# %%
print(data['Review Scores Rating'].corr(data['Review Scores Value']))
print(data['Review Scores Rating'].corr(data['Price']))
print(data['Review Scores Value'].corr(data['Price']))
# Out:
# 0.8049535401962251
# 0.06272417556864122
# 0.03547625028344432

# %%
data.drop('Review Scores Value', axis = 1, inplace = True)

# %%
print(data['Number of Reviews'].corr(data['Reviews per Month']))
print(np.abs(data['Number of Reviews'].corr(data['Price'])))
print(np.abs(data['Reviews per Month'].corr(data['Price'])))
# Out:
# 0.6000622429947832
# 0.01681918054371166
# 0.0306657286028719

# %%
data.drop('Number of Reviews', axis = 1, inplace = True)

# %%
data[['Review Scores Rating','Review Scores Accuracy']]
# Out:
#        Review Scores Rating  Review Scores Accuracy
# 9937                   89.0                     9.0
# 10483                  97.0                    10.0
# 11226                 100.0                    10.0
# 8254                   94.0                     9.0
# 2559                   87.0                     9.0
# ...                     ...                     ...
# 5191                   94.0                    10.0
# 13418                  93.0                     9.0
# 5390                    NaN                     NaN
# 860                    71.0                     8.0
# 7270                   98.0                    10.0
#
# [9626 rows x 2 columns]

# %%
print(data['Review Scores Rating'].corr(data['Review Scores Accuracy']))
print(np.abs(data['Review Scores Rating'].corr(data['Price'])))
print(np.abs(data['Review Scores Accuracy'].corr(data['Price'])))
# Out:
# 0.7594392242402848
# 0.06272417556864122
# 0.06877388229622461

# %%
data.drop('Review Scores Rating', axis = 1, inplace = True)

# %%
print(data['Review Scores Communication'].corr(data['Review Scores Checkin']))
print(np.abs(data['Review Scores Communication'].corr(data['Price'])))
print(np.abs(data['Review Scores Checkin'].corr(data['Price'])))
# Out:
# 0.7223898609785889
# 0.009249547553984704
# 0.007961702240183445

# %%
data.drop('Review Scores Communication', axis = 1, inplace = True)

# %% [markdown]
# <br>

# %%
# Compute the correlation matrix
corr = np.abs(data.drop(['Price'], axis=1).corr())
# Generate a mask for the upper triangle
mask = np.zeros_like(corr, dtype=np.bool)
mask[np.triu_indices_from(mask)] = True

# Set up the matplotlib figure
f, ax = plt.subplots(figsize=(12, 10))

# Draw the heatmap with the mask and correct aspect ratio
sns.heatmap(corr, mask=mask,vmin = 0.0, vmax=1.0, center=0.5,
            linewidths=.1, cmap="YlGnBu", cbar_kws={"shrink": .8})

plt.show()

# %% [markdown]
# En el resto de variables de "Review" seguimos viendo alta correlación con rating, lo cual tiene sentido. Pero no las eliminaremos porque son aspectos distintos que pueden ser de interés.
# <br> También vemos, como he comentado ya antes, la alta correlación de la variable "bed_bath_rooms" pero de momento lo dejaremos así para ver si enriquece el modelo más adelante.

# %% [markdown]
# <br>

# %% [markdown]
# ### Tratar los Nans:

# %%
data.columns[data.isnull().any()]
# Out:
# Index(['Host Since', 'Host Response Time', 'Host Response Rate', 'Bathrooms',
#        'Bedrooms', 'Review Scores Accuracy', 'Review Scores Cleanliness',
#        'Review Scores Checkin', 'Review Scores Location', 'Reviews per Month',
#        'bed_bath_rooms'],
#       dtype='object')

# %% [markdown]
# **Variable:**
# <br>HOST SINCE

# %%
print(f" Hay: {data['Host Since'].isnull().sum()} nans")
print(f" En porcentaje: {np.round((data['Host Since'].isnull().sum()/data.shape[0])*100,2)}%")
# Out:
#  Hay: 3 nans
#  En porcentaje: 0.03%

# %%
data.dropna(subset=['Host Since'], inplace = True)

# %% [markdown]
# **Variable:**
# <br>HOST RESPONSE TIME

# %%
print(f" Hay: {data['Host Response Time'].isnull().sum()} nans")
print(f" En porcentaje: {np.round((data['Host Response Time'].isnull().sum()/data.shape[0])*100,2)}%")
# Out:
#  Hay: 1205 nans
#  En porcentaje: 12.52%

# %%
print(f"Tipo de la variable: {data.dtypes['Host Response Time']}")
data["Host Response Time"].fillna(data["Host Response Time"].mode()[0], inplace=True)
# Out:
# Tipo de la variable: object

# %% [markdown]
# **Variable:**
# <br>HOST RESPONSE RATE

# %%
print(f"Tipo de la variable: {data.dtypes['Host Response Rate']}")
print(f"Porcentaje de nan: {np.round((data['Host Response Rate'].isnull().sum()/data.shape[0])*100,2)}%")
# Out:
# Tipo de la variable: float64
# Porcentaje de nan: 12.52%

# %% [markdown]
# Rellenamos con la media:

# %%
#Para comprobar que los nulos se cambian bien
i = data[data['Host Response Rate'].isnull()].index
print(data.loc[i[0],'Host Response Rate'])
print("La media con la que se debe rellenar es: ",data['Host Response Rate'].mean())
# Out:
# nan
# La media con la que se debe rellenar es:  94.84842005226895

# %%
data["Host Response Rate"].fillna(data["Host Response Rate"].mean(), inplace=True)

# %%
print(data.loc[i[0],'Host Response Rate'])
# Out:
# 94.84842005226895

# %% [markdown]
# <br>

# %%
data.dtypes[data.isnull().any()]
# Out:
# Bathrooms                    float64
# Bedrooms                     float64
# Review Scores Accuracy       float64
# Review Scores Cleanliness    float64
# Review Scores Checkin        float64
# Review Scores Location       float64
# Reviews per Month            float64
# bed_bath_rooms               float64
# dtype: object

# %% [markdown]
# Vemos que las que quedan son de tipo float y todas las vamos a rellenar con la media de sus datos correspondientes. <br> (Ya hemos comprobado más arriba que el porcentaje de campos vacíos es menor al 25%, por lo que podemos rellenar estos campos sin cometer grandes errores)

# %%
#Estos ceros los hemos detectado abajo, con la visualización pero lo ponemos aqui porque
#al tratarse de errores no queremos que influyan en la media
data.drop(data[data['Bedrooms']==0].index, inplace = True)
data.drop(data[data['bed_bath_rooms']==0].index, inplace = True)
data.drop(data[data['Reviews per Month']==0].index, inplace = True)

# %%
cols = data.columns[data.isnull().any()]
for col in cols:
    data[col].fillna(data[col].mean(), inplace=True)

# %% [markdown]
# <br>

# %% [markdown]
# ### Visualización de la distribución de las variable numéricas:

# %%
num_variables = [column for column, datatype in data.dtypes.items() if datatype in (np.int64, np.float64)]

# %%
for col in num_variables:
    plt.subplots(nrows=1,ncols=2,figsize=(20,5),sharex=True)
    
    plt.subplot(1,2,1)
    sns.set_theme(style="whitegrid")
    sns.boxplot(data=data, y=col, saturation = 0.6, linewidth = 1, color = '#E55D5D')

    plt.subplot(1,2,2)
    sns.set_theme(style="whitegrid")
    sns.histplot(data[col],color = '#E55D5D', bins = 20,kde = True, stat='density')

# %%
data['bed_bath_rooms'].dtype
# Out:
# dtype('float64')

# %%
print(f"Tenemos: {data.shape[0]} filas")
# Out:
# Tenemos: 8831 filas

# %% [markdown]
# Errors:
# - Bedrooms: ==0
# - bed_bath_rooms: == 0

# %% [markdown]
# Apply log a:
# - Reviews per month
# - bed_bath_rooms

# %% [markdown]
# Outliers:
# - Accomodates : >8

# %%
data = data[data['bed_bath_rooms']>0] 
data['bed_bath_rooms'] = data['bed_bath_rooms'].apply(lambda x: np.log(x))

data = data[data['Reviews per Month']>0] 
data['Reviews per Month'] = data['Reviews per Month'].apply(lambda x: np.log(x))

data = data[data['Accommodates']<8]

# %%
print(f"Tenemos: {data.shape[0]} filas")
# Out:
# Tenemos: 8586 filas

# %%
cols = ['Bedrooms','bed_bath_rooms','Reviews per Month','Accommodates']
for col in cols:
    plt.subplots(nrows=1,ncols=2,figsize=(20,5),sharex=True)
    
    plt.subplot(1,2,1)
    sns.set_theme(style="whitegrid")
    sns.boxplot(data=data, y=col, saturation = 0.6, linewidth = 1, color = '#E55D5D')

    plt.subplot(1,2,2)
    sns.set_theme(style="whitegrid")
    sns.histplot(data[col],color = '#E55D5D', bins = 20,kde = True, stat='density')

# %% [markdown]
# ### Transformación de variables categóricas:

# %%
data.dtypes[data.dtypes == 'object']
# Out:
# Host Since                      object
# Host Response Time              object
# Neighbourhood Group Cleansed    object
# Property Type                   object
# Room Type                       object
# Bed Type                        object
# Cancellation Policy             object
# dtype: object

# %% [markdown]
# **Variable:**
# <br>HOST SINCE

# %%
data['Host Since'] = data['Host Since'].apply(lambda x: datetime.strptime(str(x),'%Y-%m-%d'))

# %%
max(data['Host Since'])
# Out:
# Timestamp('2017-04-07 00:00:00')

# %% [markdown]
# En la documentación vemos que los datos se han actualizado por última vez el October 3, 2020 a las 3:03 PM. <br> Esto choca con que la fecha más reciente del Host es del año 2017, de todas formas vamos a modificar esta variable de "Host Since" en el número de año que lleva el usuario en la plataforma hasta 2020 (última modificación).

# %%
data['year'] = data['Host Since'].apply(lambda x: 2020 - x.year)

# %%
data.drop('Host Since', axis = 1, inplace = True)

# %% [markdown]
# Para las demás variables categóricas vamos a hacer un mean encoder:

# %%
cols = data.columns[data.dtypes == 'object']
# Creamos un dict para usarlo después en test
mean_map = {}
for col in cols:
    mean = data.groupby(col)['Price'].mean()
    data[col] = data[col].map(mean)    
    mean_map[col] = mean

# %% [markdown]
# <br>

# %% [markdown]
# ### Data lista:

# %%
data.shape
# Out:
# (8586, 28)

# %%
data.head()
# Out:
#        Host Response Time  Host Response Rate  Host Verifications  \
# 10483           58.616687            98.00000                   4
# 8254            58.616687           100.00000                   4
# 2559            53.827885            80.00000                   4
# 13404           53.827885           100.00000                   6
# 12905           58.616687            94.84842                   1
#
#        Neighbourhood Group Cleansed   Latitude  Longitude  Property Type  \
# 10483                     65.562632  40.428465  -3.703921      59.662002
# 8254                      65.562632  40.410959  -3.711181      59.662002
# 2559                      65.562632  40.408957  -3.711924      59.662002
# 13404                     44.251761  40.405215  -3.691093      59.662002
# 12905                     67.280859  40.429775  -3.665240      59.662002
#
#        Room Type  Accommodates  Bathrooms  Bedrooms   Bed Type  Amenities  \
# 10483  79.124311             4   1.000000       1.0  57.974075         19
# 8254   79.124311             3   1.000000       1.0  57.974075         19
# 2559   32.123102             2   1.248721       1.0  57.974075          8
# 13404  32.123102             2   1.000000       1.0  57.974075         16
# 12905  79.124311             5   1.000000       2.0  57.974075         17
#
#        Price  Guests Included  Extra People  Minimum Nights  Maximum Nights  \
# 10483  105.0                2            15               1              62
# 8254    52.0                2            15               2            1125
# 2559    20.0                1            10               6            1125
# 13404   35.0                1             0               1            1125
# 12905   70.0                2            10               3              30
#
#        Availability 365  Review Scores Accuracy  Review Scores Cleanliness  \
# 10483               324               10.000000                   10.00000
# 8254                281                9.000000                   10.00000
# 2559                343                9.000000                    7.00000
# 13404                38               10.000000                   10.00000
# 12905               223                9.417445                    9.33946
#
#        Review Scores Checkin  Review Scores Location  Cancellation Policy  \
# 10483              10.000000               10.000000            64.611685
# 8254               10.000000               10.000000            58.605365
# 2559               10.000000                9.000000            49.880756
# 13404              10.000000               10.000000            58.605365
# 12905               9.629369                9.539922            49.880756
#
#        Reviews per Month  Features  bed_bath_rooms  year
# 10483           1.778336         5        0.000000     6
# 8254            0.086178         2        0.000000     7
# 2559           -1.560648         3        0.588634     7
# 13404           0.565314         4        0.000000     4
# 12905           0.651405         4        0.693147     6

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8586 entries, 10483 to 7270
# Data columns (total 28 columns):
# Host Response Time              8586 non-null float64
# Host Response Rate              8586 non-null float64
# Host Verifications              8586 non-null int64
# Neighbourhood Group Cleansed    8586 non-null float64
# Latitude                        8586 non-null float64
# Longitude                       8586 non-null float64
# Property Type                   8586 non-null float64
# Room Type                       8586 non-null float64
# Accommodates                    8586 non-null int64
# Bathrooms                       8586 non-null float64
# Bedrooms                        8586 non-null float64
# Bed Type                        8586 non-null float64
# Amenities                       8586 non-null int64
# Price                           8586 non-null float64
# Guests Included                 8586 non-null int64
# Extra People                    8586 non-null int64
# Minimum Nights                  8586 non-null int64
# Maximum Nights                  8586 non-null int64
# Availability 365                8586 non-null int64
# Review Scores Accuracy          8586 non-null float64
# Review Scores Cleanliness       8586 non-null float64
# Review Scores Checkin           8586 non-null float64
# Review Scores Location          8586 non-null float64
# Cancellation Policy             8586 non-null float64
# Reviews per Month               8586 non-null float64
# Features                        8586 non-null int64
# bed_bath_rooms                  8586 non-null float64
# year                            8586 non-null int64
# dtypes: float64(18), int64(10)
# memory usage: 1.9 MB

# %%
data.isnull().sum()
# Out:
# Host Response Time              0
# Host Response Rate              0
# Host Verifications              0
# Neighbourhood Group Cleansed    0
# Latitude                        0
# Longitude                       0
# Property Type                   0
# Room Type                       0
# Accommodates                    0
# Bathrooms                       0
# Bedrooms                        0
# Bed Type                        0
# Amenities                       0
# Price                           0
# Guests Included                 0
# Extra People                    0
# Minimum Nights                  0
# Maximum Nights                  0
# Availability 365                0
# Review Scores Accuracy          0
# Review Scores Cleanliness       0
# Review Scores Checkin           0
# Review Scores Location          0
# Cancellation Policy             0
# Reviews per Month               0
# Features                        0
# bed_bath_rooms                  0
# year                            0
# dtype: int64

# %%
data.describe()
# Out:
#        Host Response Time  Host Response Rate  Host Verifications  \
# count         8586.000000         8586.000000         8586.000000
# mean            57.848707           94.768812            4.113324
# std              1.543155           14.305564            1.302331
# min             53.827885            0.000000            0.000000
# 25%             57.878450           94.848420            3.000000
# 50%             58.616687          100.000000            4.000000
# 75%             58.616687          100.000000            5.000000
# max             58.616687          100.000000            9.000000
#
#        Neighbourhood Group Cleansed     Latitude    Longitude  Property Type  \
# count                   8586.000000  8586.000000  8586.000000    8586.000000
# mean                      57.848707    40.420342    -3.696706      57.848707
# std                       11.630409     0.020578     0.024346       5.625033
# min                       28.407407    40.331888    -3.822403      18.666667
# 25%                       50.500000    40.409663    -3.707834      59.662002
# 50%                       65.562632    40.418165    -3.701523      59.662002
# 75%                       65.562632    40.427887    -3.693270      59.662002
# max                       67.280859    40.514247    -3.573613     150.000000
#
#          Room Type  Accommodates    Bathrooms     Bedrooms     Bed Type  \
# count  8586.000000    8586.00000  8586.000000  8586.000000  8586.000000
# mean     57.848707       2.94293     1.227138     1.293013    57.848707
# std      23.485993       1.54279     0.541542     0.588258     1.167626
# min      26.378151       1.00000     0.500000     1.000000    39.666667
# 25%      32.123102       2.00000     1.000000     1.000000    57.974075
# 50%      79.124311       2.00000     1.000000     1.000000    57.974075
# 75%      79.124311       4.00000     1.000000     1.000000    57.974075
# max      79.124311       7.00000     8.000000    10.000000    57.974075
#
#          Amenities        Price  Guests Included  Extra People  \
# count  8586.000000  8586.000000      8586.000000   8586.000000
# mean     14.263802    57.848707         1.507687      7.346844
# std       4.715895    35.069118         0.895858     10.034066
# min       0.000000    10.000000         1.000000      0.000000
# 25%      11.000000    30.000000         1.000000      0.000000
# 50%      14.000000    50.000000         1.000000      5.000000
# 75%      17.000000    76.000000         2.000000     13.000000
# max      34.000000   199.000000        16.000000    276.000000
#
#        Minimum Nights  Maximum Nights  Availability 365  \
# count     8586.000000     8586.000000       8586.000000
# mean         2.856278      870.867925        203.323550
# std          8.014552     1933.035449        128.398289
# min          1.000000        1.000000          0.000000
# 25%          1.000000      360.000000         78.000000
# 50%          2.000000     1125.000000        244.000000
# 75%          3.000000     1125.000000        321.000000
# max        365.000000   100000.000000        365.000000
#
#        Review Scores Accuracy  Review Scores Cleanliness  \
# count             8586.000000                8586.000000
# mean                 9.425811                   9.343491
# std                  0.799607                   0.876394
# min                  2.000000                   2.000000
# 25%                  9.000000                   9.000000
# 50%                  9.417445                   9.339460
# 75%                 10.000000                  10.000000
# max                 10.000000                  10.000000
#
#        Review Scores Checkin  Review Scores Location  Cancellation Policy  \
# count            8586.000000             8586.000000          8586.000000
# mean                9.635022                9.537225            57.848707
# std                 0.683298                0.683318             6.320606
# min                 2.000000                2.000000            49.880756
# 25%                 9.629369                9.000000            49.880756
# 50%                10.000000               10.000000            58.605365
# 75%                10.000000               10.000000            64.611685
# max                10.000000               10.000000           115.750000
#
#        Reviews per Month     Features  bed_bath_rooms         year
# count        8586.000000  8586.000000     8586.000000  8586.000000
# mean            0.181092     3.735966        0.332257     5.687398
# std             1.126316     1.041282        0.524684     1.620018
# min            -3.912023     1.000000       -0.693147     3.000000
# 25%            -0.462035     3.000000        0.000000     4.000000
# 50%             0.651405     4.000000        0.000000     5.000000
# 75%             0.832909     4.000000        0.693147     7.000000
# max             2.845491     8.000000        4.094345    11.000000

# %% [markdown]
# <br>
